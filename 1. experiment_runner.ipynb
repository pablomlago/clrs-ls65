# %%
from lsr.experiment import run_experiment
import numpy as np

# %%
data_dump = np.load('trajs.npz')
data = data_dump['trajs']
core = data_dump['score']
true_lengths = data_dump['lengths']

print(data.shape)
# Out:
# (16384, 15, 128)

# %% [markdown]
# Plots Trajectory-wise and Step-wise figures for a given trajectory.

# %%
run_experiment(name='test_min', path='./trajs')
# Out:
# (16384, 15, 128)
