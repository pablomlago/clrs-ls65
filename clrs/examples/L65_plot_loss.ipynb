# %%
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
def get_results(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    pattern = re.compile(r'current loss ([\d\.]+)')
    processor_type_pattern = re.compile(r'processor_type (\S+)')
    regularisation_weight_pattern = re.compile(r'regularisation_weight ([\d\.]+(?:e-?\d+)?)')


    loss_values = []

    for line in lines:
        match = pattern.search(line)
        if match:
            loss_value = float(match.group(1))
            loss_values.append(loss_value)

        # Search for 'processor_type'
        processor_type_match = processor_type_pattern.search(line)
        if processor_type_match:
            processor_type = str(processor_type_match.group(1))
        

        # Search for 'regularisation_weight'
        regularisation_weight_match = regularisation_weight_pattern.search(line)
        if regularisation_weight_match:
            regularisation_weight = regularisation_weight_match.group(1)

        
        if '(test)' in line:
            test_results = line

    print(f"Processor Type: {processor_type}")
    print(f"Regularisation Weight: {regularisation_weight}")
    print(f"Test results: {test_results}")

    plt.figure()
    plt.semilogy(loss_values)
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.title(f"Processor Type: {processor_type} - Regularisation Weight: {regularisation_weight}")
    print("#########################################")

# %%
#file_path = "/rds/user/ar2217/hpc-work/L65/clrs-ls65/slurm-44998187.out"
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45030864_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45030865_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45030866_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45030867_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45030868_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45030869_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45045906_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45045907_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45045908_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45045909_1.out")
get_results("/rds/user/ar2217/hpc-work/L65/clrs-ls65/logs_test/runs_45045910_1.out")
# Out:
# Processor Type: mpnn_l1
# Regularisation Weight: 0.0
# Test results: I0220 10:26:34.719265 23017575403648 run.py:547] (test) algo bfs : {'pi': 0.23095703125, 'score': 0.23095703125, 'examples_seen': 320000, 'step': 10000, 'algorithm': 'bfs'}
#
# #########################################
# Processor Type: mpnn_l2
# Regularisation Weight: 0.0
# Test results: I0220 10:28:54.205910 23388063039616 run.py:547] (test) algo bfs : {'pi': 1.0, 'score': 1.0, 'examples_seen': 320000, 'step': 10000, 'algorithm': 'bfs'}
#
# #########################################
# Processor Type: mpnn_l1_regularised
# Regularisation Weight: 0.01
# Test results: I0220 10:31:56.135426 22570087682176 run.py:547] (test) algo bfs : {'pi': 0.3408203125, 'score': 0.3408203125, 'examples_seen': 320000, 'step': 10000, 'algorithm': 'bfs'}
#
# #########################################
# Processor Type: mpnn_l1_regularised
# Regularisation Weight: 0.001
# ...
